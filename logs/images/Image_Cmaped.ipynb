# %%
import scipy.misc as misc
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
# %matplotlib inline

# %%
idx = 6
gt = misc.imread('../gt_%d.png'%idx)
inp = misc.imread('../inp_%d.png'%idx)
pred = misc.imread('../pred_%d.png'%idx)

# %%
plt.imshow(inp)

# %%
plt.imshow(gt, cmap=cm.Paired ,vmin=0, vmax=151)
plt.colorbar()

# %%
plt.imshow(pred,cmap=cm.Paired ,vmin=0, vmax=np.max(pred))
plt.colorbar()

# %%
print np.max(pred)
# Out:
# 6

# %%
pred.shape
# Out:
# (224, 224)
