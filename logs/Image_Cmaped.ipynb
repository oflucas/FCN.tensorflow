# %%
import scipy.misc as misc
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
# %matplotlib inline

# %%
idx = 4
gt = misc.imread('gt_%d.png'%idx)
inp = misc.imread('inp_%d.png'%idx)
pred = misc.imread('pred_%d.png'%idx)
class_num = 2 # 151 for MIT-SP

# %%
inp.shape, gt.shape, pred.shape
# Out:
# ((224, 224, 3), (224, 224), (224, 224))

# %%
plt.imshow(inp)

# %%
plt.imshow(gt, cmap=cm.Paired ,vmin=0, vmax=class_num)
plt.colorbar()

# %%
plt.imshow(pred,cmap=cm.Paired ,vmin=0, vmax=class_num)
plt.colorbar()

# %%
# kitti = misc.imread('/nfs/private/FCN.tensorflow/Data_zoo/kitti_road/data_road/training/image_2/um_000000.png')

# kitti.shape

# plt.imshow(kitti)
