# %%
import scipy.misc as misc
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
# %matplotlib inline

# %%
idx = 5
gt = misc.imread('gt_%d.png'%idx)
inp = misc.imread('inp_%d.png'%idx)
pred = misc.imread('pred_%d.png'%idx)
class_num = 2 # 151 for MIT-SP
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-56-1e2914baa918> in <module>()
#       1 idx = 5
# ----> 2 gt = misc.imread('gt_%d.png'%idx)
#       3 inp = misc.imread('inp_%d.png'%idx)
#       4 pred = misc.imread('pred_%d.png'%idx)
#       5 class_num = 2 # 151 for MIT-SP
#
# /home/luban/anaconda2/lib/python2.7/site-packages/scipy/misc/pilutil.pyc in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# /home/luban/anaconda2/lib/python2.7/site-packages/PIL/Image.pyc in open(fp, mode)
#    2475
#    2476     if filename:
# -> 2477         fp = builtins.open(filename, "rb")
#    2478         exclusive_fp = True
#    2479
#
# IOError: [Errno 2] No such file or directory: 'gt_5.png'

# %%
plt.figure(figsize=(12, 12))
plt.subplot(311)
plt.imshow(inp)
plt.ylabel('ORIGINAL')
plt.subplot(312)
plt.imshow(gt)
plt.ylabel('GROUND TRUTH')
plt.subplot(313)
plt.imshow(pred)
plt.ylabel('PREDICTION')
